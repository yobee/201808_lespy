# %%
import numpy as np
from IPython.display import Image, display_png

# %% [markdown]
# ## numpyとは

# %% [markdown]
# - 高速な行列計算と柔軟なブロードキャストを提供する効率的な多次元配列であるndarray。
# - 高速に動作し、呼び出しにループ記法を必要としない標準的な数学関数。
# - ディスクへの配列の読み書きに加え、メモリマップファイル機能を提供する入出力機能。
# - 行列計算、乱数生成、フーリエ変換といった機能。
# - C、C++、Fortranへのインタフェース。
#  ※教科書(116/597) 抜粋

# %% [markdown]
#  NumPyにはC言語呼び出しのAPIがあり、NumPyからCで書かれた外部ライブラリへ容易にデー
# タを渡すことができ、また外部ライブラリの計算結果をNumPyに戻してndarrayとして扱うこともで
# きます。この機能のおかげで、PythonはC、C++、Fortranなどで書かれた既存のコード資産へのラッ
# パーとしての位置づけを獲得してきました。NumPyはこれら既存ライブラリを簡単に呼び出せる、動
# 的インタフェースとしての役割を担っています。
# 教科書(116/597)  抜粋

# %% [markdown]
# NumPyは他の組み込みPythonオブジェクトと独立する形で、メモリの連続領域にデータを配置
# します。NumPyのアルゴリズムライブラリはCで書かれており、型検査などのオーバーヘッド
# なしにメモリ上のデータをそのまま扱うことができます。さらに標準のPythonシーケンスと比較
# したとき、NumPy配列のメモリ使用量は十分小さなものとなります。
# 教科書(117/597) 抜粋

# %%
# １００万までの整数をそれぞれ格納
my_arr = np.arange(1000000)
my_list = list(range(1000000))

# %%
# %time for _ in range(10): my_arr2 = my_arr * 2
# Out:
# CPU times: user 13.9 ms, sys: 2.07 ms, total: 16 ms
# Wall time: 13.9 ms

# %%
# %time for _ in range(10): my_list2 = [x * 2 for x in my_list]
# Out:
# CPU times: user 574 ms, sys: 157 ms, total: 731 ms
# Wall time: 739 ms

# %% [markdown]
# この例で示されるように、NumPyのアルゴリズムはPython標準で提供される同等機能と比較して
# 10倍から100倍、あるいはそれ以上に高速に動作します。さらに要求するメモリ量も格段に少なく済む
# という特徴があります。

# %% [markdown]
# ### NumPy ndarray:多次元配列オブジェクト

# %% [markdown]
# ndarray:多次元配列オブジェクト
# ndarrayに対する算術操作は、その配列要素すべてに作用します。
# NumPyが配列要素に一括計算する仕組みを見ていきたいと思います。

# %%
import numpy as np
data = np.random.randn(2, 3)

# %%
data
# Out:
# array([[-0.32242161,  2.28819804,  0.6995671 ],
#        [-0.41764462, -1.24130017,  0.16626141]])

# %% [markdown]
# 図4-1は2次元配列のインデックス参照の概念を示しています。axis0を行に、axis1を列に見立てる

# %%
display_png(Image('sc02.png'))

# %%
data
# Out:
# array([[-0.90960904, -1.83240409, -0.84041789],
#        [-0.67963256,  0.44086181, -1.80470699]])

# %%
data * 10
# Out:
# array([[ -9.09609043, -18.32404087,  -8.40417886],
#        [ -6.79632561,   4.40861805, -18.04706988]])

# %%
data.shape
# Out:
# (2, 3)

# %%
data.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ndarrayオブジェクトを生成するのに一番簡単な方法は、NumPyのarray関数を用いる方法です。

# %%
data1 = [6, 7.5, 8, 0, 1]

# %%
arr1 = np.array(data1)

# %%
arr1
# Out:
# array([6. , 7.5, 8. , 0. , 1. ])

# %% [markdown]
# ネスト構造の内側のシーケンス同士の要素数が一致する
# 場合に、ndarrayの多次元配列が生成されます。

# %%
data2 = [[1, 2, 3, 4], [5, 6, 7, 8]]

# %%
arr2 = np.array(data2)

# %%
arr2
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
arr2.shape
# Out:
# (2, 4)

# %%
data3 = [[1, 2, 3, 4], [5, 6, 7]]

# %%
arr3 = np.array(data3)

# %%
arr3
# Out:
# array([list([1, 2, 3, 4]), list([5, 6, 7])], dtype=object)

# %%
arr3.dtype
# Out:
# dtype('O')

# %% [markdown]
# ## スライスによるインデックス参照
# ndarrayはスライス記法で部分的に切り出すことができます。これはPythonのリストなどでおなじみ

# %%
display_png(Image('sc01.png'))
